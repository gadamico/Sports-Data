# %%
import pandas as pd
import sys, os

# %% [markdown]
# ## 2022 Season

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/champ_droughts.csv')
copy = df.copy()

# %%
copy.drop('Unnamed: 0', axis=1).to_csv('../data/champ_droughts.csv', index=False)

# %%
df = pd.read_csv('../data/ws_droughts.csv')

# %%
df = pd.read_csv('../data/lcsp_droughts.csv')
copy = df.copy()
copy.drop('Unnamed: 0', axis=1).to_csv('../data/lcsp_droughts.csv', index=False)

# %%
df = pd.read_csv('../data/postseason_droughts.csv')
copy = df.copy()
copy.drop('Unnamed: 0', axis=1).to_csv('../data/postseason_droughts.csv', index=False)

# %%
post_teams_22 = ['Astros (15)', 'Blue Jays (8)', 'Braves (27)', 'Cardinals (31)', 'Indians (15)',
                 'Dodgers (35)', 'Mariners (4)', 'Mets (9)', 'Phillies (14)', 'Padres (6)',
                'Rays (7)', 'Yankees (57)']

# %%
lcsp_teams_22 = ['Padres (2)', 'Yankees (46)', 'Astros (9)', 'Phillies (11)']

# %%
ws_teams_22 = ['Astros (4)', 'Phillies (7)']

# %%
champ_team_22 = 'Astros (1)'

# %%
import sys, os

# %%
sys.path.append(os.pardir)

# %%
sys.path
# Out:
# ['/Users/gadamico/Fun/Sports-Data/baseball/notebooks',
#  '/Users/gadamico/opt/anaconda3/envs/learn-env/lib/python38.zip',
#  '/Users/gadamico/opt/anaconda3/envs/learn-env/lib/python3.8',
#  '/Users/gadamico/opt/anaconda3/envs/learn-env/lib/python3.8/lib-dynload',
#  '',
#  '/Users/gadamico/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages',
#  '/Users/gadamico/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/extensions',
#  '/Users/gadamico/.ipython',
#  '..',
#  '..']

# %%
from src.update_mlb import *

# %%
update_table(post_teams=post_teams_22, lcsp_teams=lcsp_teams_22, ws_teams=ws_teams_22,
            champ_team=champ_team_22, new_year='2022')

# %%
pd.read_csv('../data/champ_droughts.csv')
# Out:
#            TEAM/YEAR     2022 2021 2020 2019 2018 2017 2016   2015  2014  ...  \
# 0        Indians (2)   1 (73)  72*  71*  70*  69*  68*  67*     66    65  ...
# 1        Rangers (0)   2 (61)   60   59   58   57   56   55     54    53  ...
# 2        Brewers (0)   3 (53)   52   51   50   49   48   47     46    45  ...
# 3         Padres (0)   3 (53)   52   51   50   49   48   47     46    45  ...
# 4       Mariners (0)   5 (45)   44   43   42   41   40   39     38    37  ...
# 5        Pirates (5)   6 (42)   41   40   39   38   37   36     35    34  ...
# 6        Orioles (3)   7 (38)   37   36   35   34   33   32     31    30  ...
# 7         Tigers (4)   8 (37)   36   35   34   33   32   31     30    29  ...
# 8           Mets (2)   9 (35)   34   33   32   31   30   29     28    27  ...
# 9      Athletics (9)  10 (32)   31   30   29   28   27   26     25    24  ...
# 10          Reds (5)  11 (31)   30   29   28   27   26   25     24    23  ...
# ...

# %% [markdown]
# ## 2023 Season

# %%
post_teams_23 = ['Astros (16)', 'Blue Jays (9)', 'Braves (28)', 'Brewers (8)', 'Diamondbacks (6)',
                'Dodgers (36)', 'Marlins (3)', 'Orioles (14)', 'Phillies (15)', 'Rangers (8)',
                'Rays (8)', 'Twins (17)']
lcsp_teams_23 = ['Astros (10)', 'Diamondbacks (2)', 'Phillies (12)', 'Rangers (2)']
ws_teams_23 = ['Diamondbacks (1)', 'Rangers (2)']
champ_team_23 = 'Rangers (0)'

# %%
update_table(post_teams=post_teams_23, lcsp_teams=lcsp_teams_23, ws_teams=ws_teams_23,
             champ_team=champ_team_23, new_year='2023')

# %%
pd.read_csv('../data/champ_droughts.csv')
# Out:
#            TEAM/YEAR     2023 2022 2021 2020 2019 2018 2017 2016   2015  ...  \
# 0        Indians (2)   1 (74)  73*  72*  71*  70*  69*  68*  67*     66  ...
# 1        Brewers (0)   2 (54)   53   52   51   50   49   48   47     46  ...
# 2         Padres (0)   2 (54)   53   52   51   50   49   48   47     46  ...
# 3       Mariners (0)   4 (46)   45   44   43   42   41   40   39     38  ...
# 4        Pirates (5)   5 (43)   42   41   40   39   38   37   36     35  ...
# 5        Orioles (3)   6 (39)   38   37   36   35   34   33   32     31  ...
# 6         Tigers (4)   7 (38)   37   36   35   34   33   32   31     30  ...
# 7           Mets (2)   8 (36)   35   34   33   32   31   30   29     28  ...
# 8      Athletics (9)   9 (33)   32   31   30   29   28   27   26     25  ...
# 9           Reds (5)  10 (32)   31   30   29   28   27   26   25     24  ...
# 10         Twins (3)  11 (31)   30   29   28   27   26   25   24     23  ...
# ...

# %% [markdown]
# ## 2024 Season

# %% [markdown]
# ### Getting Current Numbers

# %%
pd.read_csv('../data/champ_droughts.csv')
# Out:
#            TEAM/YEAR     2023 2022 2021 2020 2019 2018 2017 2016   2015  ...  \
# 0        Indians (2)   1 (74)  73*  72*  71*  70*  69*  68*  67*     66  ...
# 1        Brewers (0)   2 (54)   53   52   51   50   49   48   47     46  ...
# 2         Padres (0)   2 (54)   53   52   51   50   49   48   47     46  ...
# 3       Mariners (0)   4 (46)   45   44   43   42   41   40   39     38  ...
# 4        Pirates (5)   5 (43)   42   41   40   39   38   37   36     35  ...
# 5        Orioles (3)   6 (39)   38   37   36   35   34   33   32     31  ...
# 6         Tigers (4)   7 (38)   37   36   35   34   33   32   31     30  ...
# 7           Mets (2)   8 (36)   35   34   33   32   31   30   29     28  ...
# 8      Athletics (9)   9 (33)   32   31   30   29   28   27   26     25  ...
# 9           Reds (5)  10 (32)   31   30   29   28   27   26   25     24  ...
# 10         Twins (3)  11 (31)   30   29   28   27   26   25   24     23  ...
# ...

# %%
champ = pd.read_csv('../data/champ_droughts.csv')
champ['TEAM/YEAR'].replace('Indians (2)', 'Guardians (2)')
new_champ = champ.copy()
new_champ['TEAM/YEAR'] = champ['TEAM/YEAR'].replace('Indians (2)', 'Guardians (2)')
new_champ.to_csv('../data/champ_droughts.csv')

# %%
fixed_champ = pd.read_csv('../data/champ_droughts.csv')
fixed_champ = fixed_champ.drop('Unnamed: 0', axis=1)
fixed_champ.to_csv('../data/champ_droughts.csv', index=False)

# %%
pd.read_csv('../data/ws_droughts.csv')
# Out:
#            TEAM/YEAR     2023 2022 2021 2020 2019 2018 2017 2016  2015  ...  \
# 0       Mariners (0)   1 (46)  45*  44*  43*  42*   41   40   39    38  ...
# 1        Pirates (7)   2 (43)   42   41   40   39   38   37   36    35  ...
# 2        Brewers (1)   3 (40)   39   38   37   36   35   34   33    32  ...
# 3        Orioles (7)   4 (39)   38   37   36   35   34   33   32    31  ...
# 4     Athletics (14)   5 (32)   31   30   29   28   27   26   25    24  ...
# 5           Reds (9)   5 (32)   31   30   29   28   27   26   25    24  ...
# 6          Twins (6)   7 (31)   30   29   28   27   26   25   24    23  ...
# 7      Blue Jays (2)   8 (29)   28   27   26   25   24   23   22    21  ...
# 8         Padres (2)   9 (25)   24   23   22   21   20   19   18    17  ...
# 9         Angels (1)  10 (21)   20   19   18   17   16   15   14    13  ...
# 10       Marlins (2)  11 (20)   19   18   17   16   15   14   13    12  ...
# ...

# %%
ws = pd.read_csv('../data/ws_droughts.csv')
new_ws = ws.copy()
new_ws['TEAM/YEAR'] = ws['TEAM/YEAR'].replace('Indians (6)', 'Guardians (6)')
new_ws.to_csv('../data/ws_droughts.csv')

# %%
fixed_ws = pd.read_csv('../data/ws_droughts.csv')
fixed_ws = fixed_ws.drop('Unnamed: 0', axis=1)
fixed_ws.to_csv('../data/ws_droughts.csv', index=False)

# %%
pd.read_csv('../data/lcsp_droughts.csv')
# Out:
#            TEAM/YEAR     2023 2022 2021 2020 2019 2018 2017 2016 2015  ...  \
# 0       Pirates (14)   1 (30)  29*  28*  27*  26*   25   24   23   22  ...
# 1          Reds (12)   2 (28)   27   26   25   24   23   22   21   20  ...
# 2       Mariners (3)   3 (22)   21   20   19   18   17   16   15   14  ...
# 3          Twins (9)   4 (21)   20   19   18   17   16   15   14   13  ...
# 4        Marlins (2)   5 (20)   19   18   17   16   15   14   13   12  ...
# 5      White Sox (7)   6 (18)   17   16   15   14   13   12   11   10  ...
# 6     Athletics (19)   7 (17)   16   15   14   13   12   11   10    9  ...
# 7        Rockies (1)   8 (16)   15   14   13   12   11   10    9    8  ...
# 8         Angels (6)   9 (14)   13   12   11   10    9    8    7    6  ...
# 9        Tigers (15)  10 (10)    9    8    7    6    5    4    3    2  ...
# 10       Giants (22)   11 (9)    8    7    6    5    4    3    2    1  ...
# ...

# %%
lcsp = pd.read_csv('../data/lcsp_droughts.csv')
new_lcsp = lcsp.copy()
new_lcsp['TEAM/YEAR'] = lcsp['TEAM/YEAR'].replace('Indians (8)', 'Guardians (8)')
new_lcsp.to_csv('../data/lcsp_droughts.csv')

# %%
fixed_lcsp = pd.read_csv('../data/lcsp_droughts.csv')
fixed_lcsp = fixed_lcsp.drop('Unnamed: 0', axis=1)
fixed_lcsp.to_csv('../data/lcsp_droughts.csv', index=False)

# %%
pd.read_csv('../data/postseason_droughts.csv')
# Out:
#            TEAM/YEAR    2023 2022 2021 2020 2019 2018 2017 2016 2015  ...  \
# 0        Angels (10)   1 (9)   8*   7*    6    5    4    3    2    1  ...
# 1        Tigers (16)   1 (9)    8    7    6    5    4    3    2    1  ...
# 2       Pirates (17)   3 (8)    7    6    5    4    3    2    1    0  ...
# 3         Royals (9)   3 (8)    7    6    5    4    3    2    1    0  ...
# 4        Rockies (5)   5 (5)    4    3    2    1    0    0    7    6  ...
# 5      Nationals (6)   6 (4)    3    2    1    0    1    0    0    1  ...
# 6     Athletics (29)   7 (3)    2    1    0    0    0    3    2    1  ...
# 7          Cubs (21)   7 (3)    2    1    0    1    0    0    0    0  ...
# 8          Reds (16)   7 (3)    2    1    0    6    5    4    3    2  ...
# 9        Giants (27)  10 (2)    1    0    4    3    2    1    0    1  ...
# 10      Red Sox (25)  10 (2)    1    0    2    1    0    0    0    2  ...
# 11    White Sox (11)  10 (2)    1    0    0   11   10    9    8    7  ...
# ...

# %%
ps = pd.read_csv('../data/postseason_droughts.csv')
new_ps = ps.copy()
new_ps['TEAM/YEAR'] = ps['TEAM/YEAR'].replace('Indians (16)', 'Guardians (16)')
new_ps.to_csv('../data/postseason_droughts.csv')

# %%
fixed_ps = pd.read_csv('../data/postseason_droughts.csv')
fixed_ps = fixed_ps.drop('Unnamed: 0', axis=1)
fixed_ps.to_csv('../data/postseason_droughts.csv', index=False)

# %%
post_teams_24 = ['Astros (17)', 'Braves (29)', 'Brewers (9)', 'Dodgers (37)', 'Guardians (16)', 'Mets (10)',
                 'Orioles (15)', 'Padres (7)', 'Phillies (16)', 'Royals (9)', 'Tigers (16)', 'Yankees (58)']

# %%
lcsp_teams_24 = [
    'Dodgers (28)', 'Guardians (8)', 'Mets (8)', 'Yankees (47)'
]

# %%
ws_teams_24 = [
    'Dodgers (21)', 'Yankees (40)'
]

# %%
champ_team_24 = 'Dodgers (7)'

# %%
sys.path.append(os.pardir)

# %%
from src.update_mlb import *

# %%
update_table(post_teams=post_teams_24, lcsp_teams=lcsp_teams_24, ws_teams=ws_teams_24,
             champ_team=champ_team_24, new_year='2024')

# %%
pd.read_csv('../data/champ_droughts.csv')
# Out:
#            TEAM/YEAR     2024 2023 2022 2021 2020 2019 2018 2017 2016  ...  \
# 0      Guardians (2)   1 (75)  74*  73*  72*  71*  70*  69*  68*  67*  ...
# 1        Brewers (0)   2 (55)   54   53   52   51   50   49   48   47  ...
# 2         Padres (0)   2 (55)   54   53   52   51   50   49   48   47  ...
# 3       Mariners (0)   4 (47)   46   45   44   43   42   41   40   39  ...
# 4        Pirates (5)   5 (44)   43   42   41   40   39   38   37   36  ...
# 5        Orioles (3)   6 (40)   39   38   37   36   35   34   33   32  ...
# 6         Tigers (4)   7 (39)   38   37   36   35   34   33   32   31  ...
# 7           Mets (2)   8 (37)   36   35   34   33   32   31   30   29  ...
# 8      Athletics (9)   9 (34)   33   32   31   30   29   28   27   26  ...
# 9           Reds (5)  10 (33)   32   31   30   29   28   27   26   25  ...
# 10         Twins (3)  11 (32)   31   30   29   28   27   26   25   24  ...
# ...
